# %% [markdown]
# # <center> Trabalho 01: Exploração de Dados </center>
# ## <center> Usando a linguagem Python </center>
# ## <center> Preço de Medicamentos </center>

# %% [markdown]
# # Conjunto de dados

# %% [markdown]
# O conjunto se trata de uma amostra de dados de preços de medicamentos extraídos do portal brasileiro de dados abertos. Mais informações através do link: [http://dados.gov.br/dataset/anvisa-precos-de-medicamentos](http://dados.gov.br/dataset/anvisa-precos-de-medicamentos)

# %% [markdown]
# ## Objetivo

# %% [markdown]
# * Produzir um relatório técnico contendo a análise exploratória do conjunto de dados:
#     * Para cada variável/atributo da amostra, informar que tipo de atributo se enquandra (nominal, ordenal, intervalar, racional) bem como sua dimensão (discreto, contínuo);
#     * No campo {TP_PRODUTO}, informar a frequência em que aparece o valor {GENÉRICO} e {ESPECÌFICO}
#     * No campo {NU_PF18_INTEIRO}, calcular a média, mediana, amplitude, variância e desvio padrão.

# %%
import pandas as pd
medicamentos = pd.read_csv('./Dataset/TA_PRECOS_MEDICAMENTOS.csv', sep = ";", encoding = "latin")
medicamentos
# Out:
#               NU_CNPJ                                    NO_RAZAO_SOCIAL  \
# 0      60726692000181                   MARJAN INDÚSTRIA E COMÉRCIO LTDA
# 1      60726692000181                   MARJAN INDÚSTRIA E COMÉRCIO LTDA
# 2       4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 3      60726692000181                   MARJAN INDÚSTRIA E COMÉRCIO LTDA
# 4       4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 5       4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 6       4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 7       4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 8       4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 9       4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 10      4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 11      4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 12      4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 13      4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 14      4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 15      4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 16      4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 17      4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 18     60726692000181                   MARJAN INDÚSTRIA E COMÉRCIO LTDA
# 19      4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 20      4038750000103      LIBRA COMERCIO DE PRODUTOS FARMACEUTICOS LTDA
# 21     10588595000797                           MEDLEY FARMACÊUTICA LTDA
# 22     61299111000135                  LUPER INDÚSTRIA FARMACÊUTICA LTDA
# 23     10588595000797                           MEDLEY FARMACÊUTICA LTDA
# 24     10588595000797                           MEDLEY FARMACÊUTICA LTDA
# 25     10588595000797                           MEDLEY FARMACÊUTICA LTDA
# 26     61299111000135                  LUPER INDÚSTRIA FARMACÊUTICA LTDA
# 27      4522600000170                               LUNDBECK BRASIL LTDA
# 28     10588595000797                           MEDLEY FARMACÊUTICA LTDA
# 29     60726692000181                   MARJAN INDÚSTRIA E COMÉRCIO LTDA
# ...               ...                                                ...
# 50716  51780468000187                    JANSSEN-CILAG FARMACÊUTICA LTDA
# 50717   2685377000157                   SANOFI-AVENTIS FARMACÊUTICA LTDA
# 50718   2685377000157                   SANOFI-AVENTIS FARMACÊUTICA LTDA
# 50719   2685377000157                   SANOFI-AVENTIS FARMACÊUTICA LTDA
# 50720   2685377000157                   SANOFI-AVENTIS FARMACÊUTICA LTDA
# 50721   2685377000157                   SANOFI-AVENTIS FARMACÊUTICA LTDA
# 50722   2685377000157                   SANOFI-AVENTIS FARMACÊUTICA LTDA
# 50723   2685377000157                   SANOFI-AVENTIS FARMACÊUTICA LTDA
# 50724   2685377000157                   SANOFI-AVENTIS FARMACÊUTICA LTDA
# 50725   2685377000157                   SANOFI-AVENTIS FARMACÊUTICA LTDA
# 50726   2814497000107               CIMED INDÚSTRIA DE MEDICAMENTOS LTDA
# 50727  19570720000110                        HIPOLABOR FARMACEUTICA LTDA
# 50728  64171697000146                           ACCORD FARMACÊUTICA LTDA
# 50729  64171697000146                           ACCORD FARMACÊUTICA LTDA
# 50730  49475833000106                     BIOLAB SANUS FARMACÊUTICA LTDA
# 50731  49475833000106                     BIOLAB SANUS FARMACÊUTICA LTDA
# 50732  13078518000190  FUNDAÇÃO BAIANA DE PESQ. CIENTIFICA E DESENV. ...
# 50733  49475833000106                     BIOLAB SANUS FARMACÊUTICA LTDA
# 50734  49475833000106                     BIOLAB SANUS FARMACÊUTICA LTDA
# 50735  49475833000106                     BIOLAB SANUS FARMACÊUTICA LTDA
# 50736  49475833000106                     BIOLAB SANUS FARMACÊUTICA LTDA
# 50737  49475833000106                     BIOLAB SANUS FARMACÊUTICA LTDA
# 50738  49475833000106                     BIOLAB SANUS FARMACÊUTICA LTDA
# 50739  49475833000106                     BIOLAB SANUS FARMACÊUTICA LTDA
# 50740  49475833000106                     BIOLAB SANUS FARMACÊUTICA LTDA
# 50741  49475833000106                     BIOLAB SANUS FARMACÊUTICA LTDA
# 50742  61190096000192                        EUROFARMA LABORATÓRIOS S.A.
# 50743  13078518000190  FUNDAÇÃO BAIANA DE PESQ. CIENTIFICA E DESENV. ...
# 50744  61190096000192                        EUROFARMA LABORATÓRIOS S.A.
# 50745  61190096000192                        EUROFARMA LABORATÓRIOS S.A.
#
#          NU_REGISTRO      CO_GGREM         CO_EAN  \
# 0      1015501950021  5.248018e+14  7896226102634
# 1      1015501950072  5.248018e+14  7896226102627
# 2      1206900220020  5.238038e+14  7730711011233
# 3      1015500410028  5.248001e+14  7896226100449
# 4      1206900260022  5.238033e+14  7730711011493
# 5              SI/NC  5.238028e+14          SI/NC
# 6              SI/NC  5.238029e+14          SI/NC
# 7              SI/NC  5.238030e+14          SI/NC
# 8      1206900340018  5.238031e+14  7730711010151
# 9      1206900100025  5.238032e+14  7730711010809
# 10     1206900220012  5.238038e+14  7730711011226
# 11     1206900260014  5.238033e+14  7730711011486
# 12     1206900210051  5.238037e+14  7730711012629
# 13     1206900180029  5.238034e+14  7730711012452
# 14     1206900180037  5.238034e+14  7730711010984
# 15     1206900180010  5.238034e+14  7730711010977
# 16             SI/NC  5.238035e+14          SI/NC
# 17             SI/NC  5.238036e+14          SI/NC
# 18     1015501970022  5.248012e+14  7896226101965
# 19     1206900100017  5.238032e+14  7730711010526
# 20             SI/NC  5.238025e+14          SI/NC
# 21     1018102590026  5.250067e+14  7896422510202
# 22     1040401310034  5.243002e+14  7896622300023
# 23     1018102520044  5.250007e+14  7896422503068
# 24     1018102630044  5.250058e+14  7896422501354
# 25     1018102920034  5.250008e+14  7896422510035
# 26     1040419520060  5.243003e+14  7896622301952
# 27     1047500440133  5.242003e+14  5702157141050
# 28     1018102590050  5.250067e+14  7896422510233
# 29     1015500400011  5.248020e+14  7896226100654
# ...              ...           ...            ...
# 50716  1123634160029           NaN            NaN
# 50717  1130000580663           NaN            NaN
# 50718  1130000580681           NaN            NaN
# 50719  1130000580698           NaN            NaN
# 50720  1130002050386           NaN            NaN
# 50721  1130002050424           NaN            NaN
# 50722  1130002050459           NaN            NaN
# 50723  1130002710416           NaN            NaN
# 50724  1130000580711           NaN            NaN
# 50725  1130000580760           NaN            NaN
# 50726  1438101550047           NaN            NaN
# 50727  1134301940025           NaN            NaN
# 50728  1553700610012           NaN            NaN
# 50729  1553700610020           NaN            NaN
# 50730  1097401100136           NaN            NaN
# 50731  1097401100144           NaN            NaN
# 50732  1988300040012           NaN            NaN
# 50733  1097400740158           NaN            NaN
# 50734  1097400740166           NaN            NaN
# 50735  1097400740182           NaN            NaN
# 50736  1097400740204           NaN            NaN
# 50737  1097400740212           NaN            NaN
# 50738  1097400740239           NaN            NaN
# 50739  1097400740255           NaN            NaN
# 50740  1097400740263           NaN            NaN
# 50741  1097402440011           NaN            NaN
# 50742  1004310820047           NaN            NaN
# 50743  1988300050018           NaN            NaN
# 50744  1004311040037           NaN            NaN
# 50745  1004311040045           NaN            NaN
#
#                            NO_PRODUTO  \
# 0                             OSTENAN
# 1                             OSTENAN
# 2                        TEICOPLANINA
# 3                            AMBROTEN
# 4                        OXALIPLATINA
# 5                           LIBRACTAM
# 6                          LIBRATECAM
# 7                               LIFOS
# 8                           MEGASTROL
# 9                         METOTREXATO
# 10                       TEICOPLANINA
# 11                       OXALIPLATINA
# 12     SULBACTAM SÓDICO + AMPICILINA
# 13                         PACLITAXEL
# 14                         PACLITAXEL
# 15                         PACLITAXEL
# 16                          PIPERAZAM
# 17                             PLAXEL
# 18                           GLIMESEC
# 19                        METOTREXATO
# 20                           FLUMILIB
# 21                         GRAMCILINA
# 22                           ALCAFLOR
# 23                            AMPICIL
# 24                          FACYL 500
# 25                           AMPLOTAL
# 26                           AMOXIBEL
# 27                            LEXAPRO
# 28                         GRAMCILINA
# 29                              RADAN
# ...                               ...
# 50716                   BUDECORT AQUA
# 50717                       NOVALGINA
# 50718                       NOVALGINA
# 50719                       NOVALGINA
# 50720                          AMARYL
# 50721                          AMARYL
# 50722                          AMARYL
# 50723                        PROFENID
# 50724                       NOVALGINA
# 50725                       NOVALGINA
# 50726                       CAPTOPRIL
# 50727      MALEATO DE LEVOMEPROMAZINA
# 50728                         GENABYX
# 50729                         GENABYX
# 50730                   VASOPRIL PLUS
# 50731                   VASOPRIL PLUS
# 50732  BAHIAFARMA INSULINA HUMANA NPH
# 50733                         PRESSAT
# 50734                         PRESSAT
# 50735                         PRESSAT
# 50736                         PRESSAT
# 50737                         PRESSAT
# 50738                         PRESSAT
# 50739                         PRESSAT
# 50740                         PRESSAT
# 50741                        ENTOCORT
# 50742                             ESC
# 50743    BAHIAFARMA INSULINA HUMANA R
# 50744                    NITAZOXANIDA
# 50745                    NITAZOXANIDA
#
#                                          DS_APRESENTACAO              DS_CAS  \
# 0                               10 MG COMP REV CX COM 30         121268-17-5
# 1                               10 MG COMP REV CX COM 15         121268-17-5
# 2      400 MG PÓ LIOFILIZADO SOL INJ CX C/ 1 FR/AMP X...          99999-99-9
# 3                                   XPE ADU FR COM 100ML          18683-91-5
# 4                   50 MG PÓ LIOFILIZADO FR/AMP X 500 MG          99999-99-9
# 5                                              1 FA - 3G          99999-99-9
# 6                                           1 FA - 100MG          99999-99-9
# 7                                        1G PO LIOF 1 FA          99999-99-9
# 8                      160 MG COMP CX C/ 3 BL C/ 10 COMP          99999-99-9
# 9                  25 MG/ML SOL INJ CX C/ 1 FR/AMP 20 ML          99999-99-9
# 10     200 MG PÓ LIOFILIZADO SOL INJ CX C/ 1 FR/AMP X...          99999-99-9
# 11                100 MG PÓ LIOFILIZADO FR/AMP X 1000 MG          99999-99-9
# 12                            1 G + 2 G CT FR AMP VD INC          99999-99-9
# 13                     6 MG/ML SOL INJ CT FR/AMP X 50 ML          99999-99-9
# 14                6 MG/ML SOL INJ CX C/ 1 FR/AMP X 17 ML          99999-99-9
# 15                 6 MG/ML SOL INJ CX C/ 1 FR/AMP X 5 ML          99999-99-9
# 16                                           1 FA - 4,5G          99999-99-9
# 17                                   2300MG SOL INJ 1 FA          99999-99-9
# 18                               02MG COMP REV CX COM 30          93479-97-1
# 19                 500 MG PÓ LIOFILIZADO CX C/ 01 FR/AMP          99999-99-9
# 20                                    0,1MG/ML 5 AMP/5ML          99999-99-9
# 21                              500 MG CAP CX C/ FR C/ 8             69-52-3
# 22                                         C/100 DRAGEAS          99999-99-9
# 23                        500 MG INJ CX C/25 FA EMB MULT             69-52-3
# 24                               500MG COMP REV CX C/100          19387-91-8
# 25                                 1000 MG CX C/FA + DIL  69-52-3;33276-75-4
# 26                               250 MG SUSPENSAO 150 ML          99999-99-9
# 27              10 MG/ML SOL OR CT FR VD AMB CGT X 15 ML         219861-08-2
# 28                          1G INJ CX C/ 1 FA + DIL 3 ML             69-52-3
# 29                              300MG COMP REV CX COM 08          66357-35-5
# ...                                                  ...                 ...
# 50716  64 MCG/DOSE SUS INAL NAS CT FR SPR VD AMB X 12...                 NaN
# 50717               500 MG COM CT BL AL PLAS TRANSL X 30                 NaN
# 50718   500 MG COM CT BL AL PLAS TRANSL X 100 (EMB MULT)                 NaN
# 50719   500 MG COM CT BL AL PLAS TRANSL X 240 (EMB MULT)                 NaN
# 50720                          2 MG COM CT BL AL/AL X 30                 NaN
# 50721                          3 MG COM CT BL AL/AL X 30                 NaN
# 50722                          4 MG COM CT BL AL/AL X 30                 NaN
# 50723         200 MG COM REV LIB RETARD CT BL AL/AL X 10                 NaN
# 50724                  1 G COM CT BL AL PLAS TRANSL X 10                 NaN
# 50725  1 G COM CT BL AL PLAS TRANSL X 100 (EMB MÚLTIPLA)                 NaN
# 50726     25 MG COM CT BL AL PLAS TRANS X 500 (EMB HOSP)                 NaN
# 50727           100 MG COM REV CX BL AL PLAS TRANS X 500                 NaN
# 50728            200 MG PO LIOF INJ CT FA VD INC X 10 ML                 NaN
# 50729           1000 MG PO LIOF INJ CT FA VD INC X 50 ML                 NaN
# 50730                   10 MG + 25 MG COM CT STR AL X 60                 NaN
# 50731                 20 MG + 12,5 MG COM CT STR AL X 60                 NaN
# 50732             100 UI/ML SUS INJ CT FA VD INC X 10 ML                 NaN
# 50733                    5 MG COM CT BL AL PLAS AMB X 20                 NaN
# 50734                   5 MG COM CT BL AL PLAS AMB X 30                  NaN
# 50735                   5 MG COM CT BL AL PLAS AMB X 60                  NaN
# 50736                  10 MG COM CT BL AL PLAS AMB X 20                  NaN
# 50737                  10 MG COM CT BL AL PLAS AMB X 30                  NaN
# 50738                   10 MG COM CT BL AL PLAS AMB X 60                 NaN
# 50739                2,5 MG COM CT BL AL PLAS AMB X 30                   NaN
# 50740                  2,5 MG COM CT BL AL PLAS AMB X 60                 NaN
# 50741            3 MG CAP GEL MICROG CT FR PLAS OPC X 45                 NaN
# 50742            10 MG COM REV CT BL AL PLAS TRANS X 60                  NaN
# 50743             100 UI/ML SOL INJ CT FA VD INC X 10 ML                 NaN
# 50744  20 MG/ML PÓ SUS OR CT FR VD AMB X 45 ML + SER DOS                 NaN
# 50745  20 MG/ML PÓ SUS OR CT FR VD AMB X 100 ML + SER...                 NaN
#
#                                 DS_SUBSTANCIA  TP_PRODUTO TP_LCCT  \
# 0          ALENDRONATO DE SÓDIO TRI-HIDRATADO         4.0       N
# 1          ALENDRONATO DE SÓDIO TRI-HIDRATADO         4.0       N
# 2                                       NC/NI         1.0       I
# 3                                    ambroxol         4.0       N
# 4                                       NC/NI         1.0       I
# 5                                       NC/NI         4.0      II
# 6                                       NC/NI         4.0       I
# 7                                       NC/NI         4.0       I
# 8                                       NC/NI         4.0       I
# 9                                       NC/NI         4.0       I
# 10                                      NC/NI         1.0       I
# 11                                      NC/NI         1.0       I
# 12                                      NC/NI         4.0      II
# 13                                      NC/NI         1.0       I
# 14                                      NC/NI         1.0       I
# 15                                      NC/NI         4.0       I
# 16                                      NC/NI         4.0      II
# 17                                      NC/NI         4.0       I
# 18                                glimepirida         4.0       N
# 19                                      NC/NI         4.0       I
# 20                                      NC/NI         4.0       I
# 21                          ampicilina sódica         4.0       I
# 22                                      NC/NI         9.0       N
# 23                          ampicilina sódica         4.0       I
# 24                                  tinidazol         4.0       N
# 25     ampicilina sódica;ampicilina benzatina         4.0      II
# 26                                      NC/NI         4.0       I
# 27                    oxalato de escitalopram         5.0       I
# 28                          ampicilina sódica         4.0       I
# 29                                 ranitidina         4.0       N
# ...                                       ...         ...     ...
# 50716                                     NaN         NaN     NaN
# 50717                                     NaN         NaN     NaN
# 50718                                     NaN         NaN     NaN
# 50719                                     NaN         NaN     NaN
# 50720                                     NaN         NaN     NaN
# 50721                                     NaN         NaN     NaN
# 50722                                     NaN         NaN     NaN
# 50723                                     NaN         NaN     NaN
# 50724                                     NaN         NaN     NaN
# 50725                                     NaN         NaN     NaN
# 50726                                     NaN         NaN     NaN
# 50727                                     NaN         NaN     NaN
# 50728                                     NaN         NaN     NaN
# 50729                                     NaN         NaN     NaN
# 50730                                     NaN         NaN     NaN
# 50731                                     NaN         NaN     NaN
# 50732                                     NaN         NaN     NaN
# 50733                                     NaN         NaN     NaN
# 50734                                     NaN         NaN     NaN
# 50735                                     NaN         NaN     NaN
# 50736                                     NaN         NaN     NaN
# 50737                                     NaN         NaN     NaN
# 50738                                     NaN         NaN     NaN
# 50739                                     NaN         NaN     NaN
# 50740                                     NaN         NaN     NaN
# 50741                                     NaN         NaN     NaN
# 50742                                     NaN         NaN     NaN
# 50743                                     NaN         NaN     NaN
# 50744                                     NaN         NaN     NaN
# 50745                                     NaN         NaN     NaN
#
#       ST_REST_HOSP ST_CAP ST_CONFAZ87  NU_PF0_INTEIRO  NU_PF18_INTEIRO
# 0                N      N           N             NaN            76.44
# 1                N      N           N             NaN            38.39
# 2                N      N           N             0.0           296.38
# 3                N      N           N             0.0            12.88
# 4                N      N           N             0.0          1186.81
# 5                N      N           N             0.0             0.00
# 6                N      N           N             0.0             0.00
# 7                N      N           N             0.0             0.00
# 8                N      N           N             0.0             3.07
# 9                N      N           N             0.0           154.65
# 10               N      N           N             0.0           148.46
# 11               N      N           N             0.0          2373.63
# 12               N      N           N             0.0            29.59
# 13               N      N           N             0.0          4122.12
# 14               N      N           N             0.0          1388.75
# 15               N      N           N             0.0           417.13
# 16               N      N           N             0.0             0.00
# 17               N      N           N             0.0             0.00
# 18               N      N           N             0.0            26.95
# 19               N      N           N             0.0           154.63
# 20               N      N           N             0.0             0.00
# 21               N      N           N             0.0             5.57
# 22               N      N           N             0.0            17.90
# 23               N      N           N             0.0            84.12
# 24               N      N           N             0.0            33.33
# 25               N      N           N             0.0             7.93
# 26               N      N           N             0.0            19.32
# 27               N      N           N             NaN            64.27
# 28               N      N           N             0.0             3.44
# 29               N      N           N             0.0            20.25
# ...            ...    ...         ...             ...              ...
# 50716          NaN    NaN         NaN             NaN              NaN
# 50717          NaN    NaN         NaN             NaN              NaN
# 50718          NaN    NaN         NaN             NaN              NaN
# 50719          NaN    NaN         NaN             NaN              NaN
# 50720          NaN    NaN         NaN             NaN              NaN
# 50721          NaN    NaN         NaN             NaN              NaN
# 50722          NaN    NaN         NaN             NaN              NaN
# 50723          NaN    NaN         NaN             NaN              NaN
# 50724          NaN    NaN         NaN             NaN              NaN
# 50725          NaN    NaN         NaN             NaN              NaN
# 50726          NaN    NaN         NaN             NaN              NaN
# 50727          NaN    NaN         NaN             NaN              NaN
# 50728          NaN    NaN         NaN             NaN              NaN
# 50729          NaN    NaN         NaN             NaN              NaN
# 50730          NaN    NaN         NaN             NaN              NaN
# 50731          NaN    NaN         NaN             NaN              NaN
# 50732          NaN    NaN         NaN             NaN              NaN
# 50733          NaN    NaN         NaN             NaN              NaN
# 50734          NaN    NaN         NaN             NaN              NaN
# 50735          NaN    NaN         NaN             NaN              NaN
# 50736          NaN    NaN         NaN             NaN              NaN
# 50737          NaN    NaN         NaN             NaN              NaN
# 50738          NaN    NaN         NaN             NaN              NaN
# 50739          NaN    NaN         NaN             NaN              NaN
# 50740          NaN    NaN         NaN             NaN              NaN
# 50741          NaN    NaN         NaN             NaN              NaN
# 50742          NaN    NaN         NaN             NaN              NaN
# 50743          NaN    NaN         NaN             NaN              NaN
# 50744          NaN    NaN         NaN             NaN              NaN
# 50745          NaN    NaN         NaN             NaN              NaN
#
# [50746 rows x 16 columns]

# %% [markdown]
# ### Variáveis

# %% [markdown]
# | Campo      | Descrição                     | tipo       | tipo    |
# | ---------- | ----------------------------- | ---------- | ------- |
# | NU_CNPJ    | código de identificação da pessoa jurídica | Nominal   | discreto |
# | NO_RAZAO_SOCIAL | Razão Social da Pessoa Jurídica | Nominal | discreto |
# | NU_REGISTRO  | Número de registro do medicamento na Anvisa | Nominal   | discreto    |
# | CO_GGREM | Código da apresentação de um produtor | Nominal  | discreto      |
# | CO_EAN  | Número que representa o código de barras do produto. |  Nominal  |  discreto  |
# | NO_PRODUTO | Nome do medicamento. | Nominal  | discreto        |
# | DS_APRESENTACAO | Descrição da apresentação de um produto. |  Nominal   | discreto   |
# | DS_CAS | Número de registro presente no banco de dados do Chemical Abstract Service - CAS, onde são designados às substâncias, de maneira sequencial, à medida que estas são colocadas na Base de Dados do CAS. Desta forma, cada número de registro CAS é um identificador numérico único, que designa apenas uma substância e que não possui significado químico algum. |  Ordinal  | discreto       |
# | DS_SUBSTANCIA | Nome da substância da apresentação do medicamento. |  Nominal   | discreto    |
# | TP_PRODUTO | Tipo do produtor referente à apresentação. Valores de domínio: 1- Genérico, 2 - Patente, 3 - Referência, 4 - Similar, 5 - Novo, 6 - Específico, 7 - Biológicos, 8 - Dinamizado, 9 - Fitoterápico, 10 - Radiofármaco, 11 - Biológicos Novos | Ordinal | discreto  |
# | TP_LCCT | Indicador de Medicamento com ou sem crédito tributário de PIS/PASEP e COFINS. Assume os valores: I, II, III, N e NA. | Nominal |  discreto    |
# | ST_REST_HOSP | Indica que o medicamento é ou não de venda exclusiva a hospitais. | Nominal | discreto |
# | ST_CAP | Indica que o medicamento está ou não na lista do cap e por isso devera ser comercializado junto ao governo com preços diferenciados, sendo um desconto mínimo obrigatório a ser aplicado pelas distribuidoras e empresas produtoras de medicamentos ao preço de produtos vendidos a entes da administração pública. A aplicação do coeficiente estabelece um preço teto para compras governamentais, a partir do qual se deve iniciar o processo de negociação. | Nominal  |  discreto |
# | ST_CONFAZ87 | Indica que o medicamento está ou não na lista do confaz que isenta de ICMS algumas apresentações quando vendidas a entes da Administração Pública. | Nominal | discreto |
# | NU_PF0_INTEIRO | Preço Fábrica de teto permitido para a comercialização com isenção do imposto de ICMS. | Racional | contínuo  |
# | NU_PF18_INTEIRO | Preço Fábrica de teto permitido para a comercialização sem isenção do imposto de ICMS. | Racional |  contínuo         |

# %% [markdown]
# ### Avaliação do campo {TP_PRODUTO}

# %% [markdown]
# Sabe-se que o campo {TP_PRODUTO} pode conter 11 valores possíveis:
# 1. Genérico
# 2. Patente
# 3. Referência
# 4. Similar
# 5. Novo
# 6. Específico
# 7. Biológicos
# 8. Dinamizado
# 9. Fitoterápico
# 10. Radiofármacos
# 11. Biológicos Novos
#
# O problema solicita que informe a frequência com que aparece os valores **Genérico** [1] e **Específico** [6]

# %%
pd.crosstab(index=medicamentos["TP_PRODUTO"], columns = "count").apply(lambda x: (x/x.sum())*100, axis=0)
# Out:
# col_0           count
# TP_PRODUTO
# 1.0         27.112258
# 3.0          0.008191
# 4.0         43.633534
# 5.0         14.735635
# 6.0          8.750051
# 7.0          4.312569
# 8.0          0.296924
# 9.0          1.030020
# 10.0         0.004096
# 11.0         0.116722

# %% [markdown]
# O código acima informa que o **Genérico** tem frequência aproximada de 0.271 (27.1%) e **Específico** tem frequência aproximada de 0.087 (8.7%)

# %% [markdown]
# ### Avaliação do Campo {NU_PF18_INTEIRO}

# %%
import numpy as np

# %% [markdown]
# Cálculo da média do campo:

# %%
np.nanmean(medicamentos["NU_PF18_INTEIRO"])
# Out:
# 384.19651559873734

# %% [markdown]
# Cálculo da mediana do campo:

# %%
np.nanmedian(medicamentos["NU_PF18_INTEIRO"])
# Out:
# 33.630000000000003

# %% [markdown]
# Cálculo da Amplitude do campo:

# %%
np.nanmax(medicamentos["NU_PF18_INTEIRO"]) - np.nanmin(medicamentos["NU_PF18_INTEIRO"])
# Out:
# 372185.40999999997

# %% [markdown]
# Cálculo da variancia do campo:

# %%
np.nanvar(medicamentos["NU_PF18_INTEIRO"])
# Out:
# 12009210.339989169

# %% [markdown]
# Cálculo do Desvio Padrão do campo:

# %%
np.nanstd(medicamentos["NU_PF18_INTEIRO"])
# Out:
# 3465.430758215949
